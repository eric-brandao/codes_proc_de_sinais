# %% [markdown]
# # Do contínuo ao discreto
#
# Neste notebook exploramos como é um sinal discreto no computador. Vamos mostrar duas versões de um seno amostrado.

# %%
# importar as bibliotecas necessárias
import numpy as np # arrays
import matplotlib.pyplot as plt # plots
plt.rcParams.update({'font.size': 14})

# %% [markdown]
# Vamos criar um seno, entre 0 [s] e 1[s], com frequência 2 [Hz]. Neste primeiro exemplo a taxa de amostragem será alta ($F_{s1} = 1000 [Hz])$

# %%
Fs_1 = 1000
time = np.arange(0, 1, 1/Fs_1)
xt_1 = np.sin(2*np.pi*2*time)

plt.figure()
plt.plot(time, xt_1, 'r', linewidth = 2)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude [-]')
plt.grid(which='both', axis='both')
plt.xlim((0,1))
plt.ylim((-1.6,1.6));

# %% [markdown]
# ## Exemplo 1
#
# Vamos explorar aspectos como o tamanho do sinal (número de amostras) e o vetor temporal

# %%
print('O número de amostras no sinal é {}.'.format(len(time)))
print('o vetor temporal é {}'.format(time))
# Out:
# O número de amostras no sinal é 1000.
# o vetor temporal é [0.    0.001 0.002 0.003 0.004 0.005 0.006 0.007 0.008 0.009 0.01  0.011
#  0.012 0.013 0.014 0.015 0.016 0.017 0.018 0.019 0.02  0.021 0.022 0.023
#  0.024 0.025 0.026 0.027 0.028 0.029 0.03  0.031 0.032 0.033 0.034 0.035
#  0.036 0.037 0.038 0.039 0.04  0.041 0.042 0.043 0.044 0.045 0.046 0.047
#  0.048 0.049 0.05  0.051 0.052 0.053 0.054 0.055 0.056 0.057 0.058 0.059
#  0.06  0.061 0.062 0.063 0.064 0.065 0.066 0.067 0.068 0.069 0.07  0.071
#  0.072 0.073 0.074 0.075 0.076 0.077 0.078 0.079 0.08  0.081 0.082 0.083
#  0.084 0.085 0.086 0.087 0.088 0.089 0.09  0.091 0.092 0.093 0.094 0.095
#  0.096 0.097 0.098 0.099 0.1   0.101 0.102 0.103 0.104 0.105 0.106 0.107
#  0.108 0.109 0.11  0.111 0.112 0.113 0.114 0.115 0.116 0.117 0.118 0.119
#  0.12  0.121 0.122 0.123 0.124 0.125 0.126 0.127 0.128 0.129 0.13  0.131
#  0.132 0.133 0.134 0.135 0.136 0.137 0.138 0.139 0.14  0.141 0.142 0.143
# ...

# %% [markdown]
# ## Exemplo 2
#
# Vamos criar um seno, entre 0 [s] e 1[s], com frequência 2 [Hz]. Neste segundo exemplo vamos mudar a taxa de amostragem e averiguar o que ocorre.

# %%
Fs_2 = 50
time2 = np.arange(0, 1, 1/Fs_2)
xt_2 = np.sin(2*np.pi*2*time2)

plt.figure()
plt.plot(time, xt_1, 'r', linewidth = 2)
plt.stem(time2, xt_2, '-b', label = r"$F_s = {}$ [Hz]".format(Fs_2), basefmt=" ", use_line_collection=  True)
plt.legend(loc = 'upper right')
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude [-]')
plt.grid(which='both', axis='both')
plt.xlim((0,1))
plt.ylim((-1.6,1.6));
